# %%
# !git lfs install
# !git clone https://huggingface.co/stabilityai/stable-diffusion-2-1-unclip
# Out:
# Error: Failed to call git rev-parse --git-dir: exit status 128
# Git LFS initialized.
# Cloning into 'stable-diffusion-2-1-unclip'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 92 (delta 28), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (92/92), 1.58 MiB | 7.81 MiB/s, done.
# Filtering content: 100% (22/22), 26.68 GiB | 45.53 MiB/s, done.
# Encountered 2 file(s) that may not have been copied correctly on Windows:
# 	sd21-unclip-l.ckpt
# 	sd21-unclip-h.ckpt
#
# See: `git lfs help smudge` for more details.

# %%
import requests
import torch
from PIL import Image
from io import BytesIO

from diffusers import StableUnCLIPImg2ImgPipeline

#Start the StableUnCLIP Image variations pipeline
pipe = StableUnCLIPImg2ImgPipeline.from_pretrained(
    "stabilityai/stable-diffusion-2-1-unclip", torch_dtype=torch.float16, variation="fp16"
)
pipe = pipe.to("cuda")

init_image = Image.open('/content/drive/MyDrive/VAE/CoolCats/5.png').convert("RGB")

#Pipe to make the variation
images = pipe(init_image).images
images[0].save("tarsila_variation.png")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-db7be2420d3e> in <cell line: 6>()
#       4 from io import BytesIO
#       5
# ----> 6 from diffusers import StableUnCLIPImg2ImgPipeline
#       7
#       8 #Start the StableUnCLIP Image variations pipeline
#
# ModuleNotFoundError: No module named 'diffusers'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
